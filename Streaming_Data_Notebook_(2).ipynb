# %% [markdown]
# <a href="https://colab.research.google.com/github/ljzier/ST-554-repo/blob/main/Streaming_Data_Notebook_(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Example to show word count using spark SQL
#
# Import necessary things!

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()
from pyspark.sql.functions import explode, split
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/04/08 13:10:32 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# Read in the data from a local source into a Spark SQL style data frame. We'll use the Oliver Twist chapter we created a while back.

# %%
chap1 = spark.read.text("data/chap1.txt")
chap1.show()
chap1.schema
# Out:
# +--------------------+
# |               value|
# +--------------------+
# |chapter i  treats...|
# +--------------------+
# StructType([StructField('value', StringType(), True)])

# %% [markdown]
# Now we'll use `split(str, regex, limit)`: Splits str around occurrences that match regex and returns an array with a length of at most limit.
# Remember we have lazy eval though!

# %%
split(chap1.value, " ")
# Out:
# Column<'split(value, ' ', -1)'>

# %% [markdown]
# With the result of that, we'll use `explode()`: Separates the elements of array expr into multiple rows, or the elements of map expr into multiple rows and columns

# %%
explode(split(chap1.value, " "))
# Out:
# Column<'explode(split(value, ' ', -1))'>

# %% [markdown]
# As the column name isn't great, let's create an alias for the column name so it is easier to use.

# %%
explode(split(chap1.value, " ")).alias("word")
# Out:
# Column<'explode(split(value, ' ', -1)) AS word'>

# %% [markdown]
# Ok, so now we have a column object that we can select from our original `chap1` data frame.  We need to use the select method.
# ([syntax and more info](https://spark.apache.org/docs/latest/api/python/reference/api/pyspark.sql.DataFrame.select.html))

# %%
col = explode(split(chap1.value, " ")).alias("word")
chap1.select(col)
# Out:
# DataFrame[word: string]

# %% [markdown]
# Use the `.show()` method to actually get the data back!

# %%
words = chap1.select(col)
words.show()
# Out:
# +-------------+
# |         word|
# +-------------+
# |      chapter|
# |            i|
# |             |
# |       treats|
# |           of|
# |          the|
# |        place|
# |        where|
# |       oliver|
# |        twist|
# |          was|
# |         born|
# |          and|
# |           of|
# |          the|
# |circumstances|
# |    attending|
# |          his|
# |        birth|
# |             |
# +-------------+
# only showing top 20 rows

# %% [markdown]
# Ok, that was a good check to make sure we had what we wanted.  Now we want to count the number of times each word occurs.  We'll use `groupBy()` and `count()` to do so.

# %%
words.groupBy("word").count()
# Out:
# DataFrame[word: string, count: bigint]

# %% [markdown]
# Let's use `.show()` to execute all the steps above and get something back!

# %%
counts = words.groupBy("word").count()
counts.show(30)
# Out:
# +-------------+-----+
# |         word|count|
# +-------------+-----+
# |         some|    2|
# |          few|    1|
# |         hope|    1|
# |    overseers|    2|
# |   surrounded|    1|
# |    biography|    1|
# |  perspective|    1|
# |circumstances|    1|
# |  articulated|    1|
# |        among|    1|
# |          day|    1|
# |         lips|    1|
# |    appendage|    1|
# |       raised|    2|
# |      whether|    1|
# |          did|    2|
# |        space|    1|
# |    existence|    1|
# |          two|    1|
# |     instance|    1|
# |    buildings|    1|
# |    strangers|    1|
# |     occurred|    1|
# |      inmates|    1|
# |      backand|    1|
# |       within|    1|
# |       favour|    1|
# |        could|    3|
# |          him|    2|
# |       badged|    1|
# +-------------+-----+
# only showing top 30 rows

# %% [markdown]
# Lastly, let's sort it and show some of the results.

# %%
counts.sort('count', ascending = False).show()
# Out:
# +-----+-----+
# | word|count|
# +-----+-----+
# |  the|   75|
# |     |   40|
# |  and|   35|
# |   of|   35|
# |    a|   33|
# |   to|   27|
# |   in|   22|
# |  was|   17|
# |   it|   13|
# |  her|   13|
# |  had|   12|
# | have|   12|
# | that|   12|
# |   by|   11|
# |  she|   11|
# | been|   11|
# |  his|   11|
# |   he|   11|
# |   on|   10|
# |which|   10|
# +-----+-----+
# only showing top 20 rows

# %% [markdown]
# # Example Using Spark Structured Streaming
#
# First read in functions we need.

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()
from pyspark.sql.types import StructType
from pyspark.sql.functions import explode, split

# %% [markdown]
# ## Step 1: Read in the stream
#
# In this case, set up that we are *listening* to a folder call `csv_files` for the addition of new `.csv` files. We'll set up the schema for the resulting SQL style data frame.

# %%
myschema = StructType().add("value", "string")
chaps = spark.readStream.schema(myschema).csv("csv_files")

# %% [markdown]
# ## Step 2: Set up transformations/aggregations to do
#
# We'll basically pull the exact code from above to act on our `chaps` object.

# %%
words = chaps.select(explode(split(chaps.value, " ")).alias("word"))
#now count the words and sort it.
wordCounts = words \
                .groupBy("word") \
                .count() \
                .sort('count', ascending = False)

# %%
wordCounts
# Out:
# DataFrame[word: string, count: bigint]

# %% [markdown]
# ## Step 3 & 4: Set up Writing of the Query to an Output Source and `.start()` the Query
#
# Now we'll use the `.writeStream` method to output the result of this to the console (we'll talk more about what this all means in a bit). The `.start()` method instructs the query to being looking for data.
#
# The output below shows the result of dropping the `chap1.txt` file into the folder and then the `chap2.txt` file (once the query was running).

# %%
query = wordCounts.writeStream.outputMode("complete").format("console").start()
# Out:
# 26/04/08 13:11:04 WARN ResolveWriteToStream: Temporary checkpoint location created which is deleted normally when the query didn't fail: /tmp/temporary-d49251c4-695c-440b-8d0f-136c61745e48. If it's required to delete it under any circumstances, please set spark.sql.streaming.forceDeleteTempCheckpointLocation to true. Important to know deleting temp checkpoint folder is best effort.
# 26/04/08 13:11:04 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# +------+-----+
# |  word|count|
# +------+-----+
# |   the|  332|
# |      |  214|
# |     a|  165|
# |   and|  153|
# |    of|  148|
# |    to|  120|
# |   was|   95|
# |    in|   93|
# |    he|   62|
# |   had|   60|
# |    it|   55|
# |   his|   51|
# |  that|   50|
# |oliver|   47|
# |   for|   46|
# |  with|   44|
# |   him|   42|
# |     i|   39|
# |  said|   36|
# |    at|   35|
# +------+-----+
# only showing top 20 rows

# %% [markdown]
# Great! Now that it is *listening* we can start adding files to the `csv_files` folder and see Spark update with new data!

# %%
#stop query
query.stop()

# %% [markdown]
# # Example Creating Data Using the `rate` Format
#
# Let's just see how to generate data using the `rate` format. This is just data that can be used to play around with methods and get things working.

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()
rateDF = spark.readStream.format("rate").load()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/04/08 13:14:34 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
rateDF
# Out:
# DataFrame[timestamp: timestamp, value: bigint]

# %%
writeDF = rateDF.writeStream.outputMode("append").format("console").start()
# Out:
# 26/04/08 13:14:47 WARN ResolveWriteToStream: Temporary checkpoint location created which is deleted normally when the query didn't fail: /tmp/temporary-ce18a333-cea1-44d0-8296-7d712c29a1f9. If it's required to delete it under any circumstances, please set spark.sql.streaming.forceDeleteTempCheckpointLocation to true. Important to know deleting temp checkpoint folder is best effort.
# 26/04/08 13:14:47 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# +---------+-----+
# |timestamp|value|
# +---------+-----+
# +---------+-----+
# -------------------------------------------
# Batch: 1
# -------------------------------------------
# +--------------------+-----+
# |           timestamp|value|
# +--------------------+-----+
# |2026-04-08 13:14:...|    0|
# +--------------------+-----+
#
# -------------------------------------------
# Batch: 2
# -------------------------------------------
# +--------------------+-----+
# |           timestamp|value|
# +--------------------+-----+
# |2026-04-08 13:14:...|    1|
# +--------------------+-----+
#
# -------------------------------------------
# Batch: 3
# -------------------------------------------
# +--------------------+-----+
# |           timestamp|value|
# +--------------------+-----+
# |2026-04-08 13:14:...|    2|
# +--------------------+-----+
#
# -------------------------------------------
# Batch: 4
# -------------------------------------------
# +--------------------+-----+
# |           timestamp|value|
# +--------------------+-----+
# |2026-04-08 13:14:...|    3|
# +--------------------+-----+
#
# -------------------------------------------
# Batch: 5
# -------------------------------------------
# +--------------------+-----+
# |           timestamp|value|
# +--------------------+-----+
# |2026-04-08 13:14:...|    4|
# +--------------------+-----+

# %% [markdown]
# Now *usually* we can stop the query (but this doesn't work well in notebooks... I sometimes have to change the kernel to get it to stop but running the below code sometimes works). Generally, we'll want to output to a file or a console rather than within a notebook.

# %%
writeDF.stop()
# Out:
# 26/04/08 13:14:53 WARN DAGScheduler: Failed to cancel job group e29ad720-45f2-4a93-8585-478d286163ed. Cannot find active jobs for it.
# 26/04/08 13:14:53 WARN DAGScheduler: Failed to cancel job group e29ad720-45f2-4a93-8585-478d286163ed. Cannot find active jobs for it.

# %% [markdown]
# Great, we can easily add some transformations in that would allow us to check functionality.

# %%
from pyspark.sql.functions import col, pow
manipDF = rateDF.withColumn("squared_value", pow(col("value"), 2))
writeDF = manipDF.writeStream.outputMode("append").format("console").start()
# Out:
# 26/04/08 13:15:24 WARN ResolveWriteToStream: Temporary checkpoint location created which is deleted normally when the query didn't fail: /tmp/temporary-910fc93c-22be-40f1-b1fb-4dd8ebe9c4b6. If it's required to delete it under any circumstances, please set spark.sql.streaming.forceDeleteTempCheckpointLocation to true. Important to know deleting temp checkpoint folder is best effort.
# 26/04/08 13:15:24 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# +---------+-----+-------------+
# |timestamp|value|squared_value|
# +---------+-----+-------------+
# +---------+-----+-------------+
#
# -------------------------------------------
# Batch: 1
# -------------------------------------------
# +--------------------+-----+-------------+
# |           timestamp|value|squared_value|
# +--------------------+-----+-------------+
# |2026-04-08 13:15:...|    0|          0.0|
# +--------------------+-----+-------------+
#
# -------------------------------------------
# Batch: 2
# -------------------------------------------
# +--------------------+-----+-------------+
# |           timestamp|value|squared_value|
# +--------------------+-----+-------------+
# |2026-04-08 13:15:...|    1|          1.0|
# +--------------------+-----+-------------+
#
# -------------------------------------------
# Batch: 3
# -------------------------------------------
# +--------------------+-----+-------------+
# |           timestamp|value|squared_value|
# +--------------------+-----+-------------+
# |2026-04-08 13:15:...|    2|          4.0|
# +--------------------+-----+-------------+
#
# -------------------------------------------
# Batch: 4
# -------------------------------------------
# +--------------------+-----+-------------+
# |           timestamp|value|squared_value|
# +--------------------+-----+-------------+
# |2026-04-08 13:15:...|    3|          9.0|
# +--------------------+-----+-------------+
#
# -------------------------------------------
# Batch: 5
# -------------------------------------------
# +--------------------+-----+-------------+
# |           timestamp|value|squared_value|
# +--------------------+-----+-------------+
# |2026-04-08 13:15:...|    4|         16.0|
# +--------------------+-----+-------------+
#
# -------------------------------------------
# Batch: 6
# -------------------------------------------
# +--------------------+-----+-------------+
# |           timestamp|value|squared_value|
# +--------------------+-----+-------------+
# |2026-04-08 13:15:...|    5|         25.0|
# +--------------------+-----+-------------+

# %%
writeDF.stop()
# Out:
# 26/04/08 13:15:30 WARN DAGScheduler: Failed to cancel job group 607f7c16-3b61-40d1-861c-ca7f8d2f1028. Cannot find active jobs for it.
# 26/04/08 13:15:30 WARN DAGScheduler: Failed to cancel job group 607f7c16-3b61-40d1-861c-ca7f8d2f1028. Cannot find active jobs for it.

# %% [markdown]
# # Writing Stream Example `memory` Format
#
# We can write a table to memory and then access it via SQL style commands.

# %%
writeTable = manipDF.writeStream \
                    .format("memory") \
                    .queryName("my_table") \
                    .start()
# Out:
# 26/04/08 13:15:35 WARN ResolveWriteToStream: Temporary checkpoint location created which is deleted normally when the query didn't fail: /tmp/temporary-3877cb23-c07e-43f6-930d-8cca83702e35. If it's required to delete it under any circumstances, please set spark.sql.streaming.forceDeleteTempCheckpointLocation to true. Important to know deleting temp checkpoint folder is best effort.
# 26/04/08 13:15:35 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.

# %% [markdown]
# Now there is a table that exists for us called `my_table`. We can use `spark.sql()` to access it.

# %%
spark.sql("select * from my_table").show()
# Out:
# +--------------------+-----+-------------+
# |           timestamp|value|squared_value|
# +--------------------+-----+-------------+
# |2026-04-08 13:15:...|    0|          0.0|
# |2026-04-08 13:15:...|    1|          1.0|
# |2026-04-08 13:15:...|    2|          4.0|
# |2026-04-08 13:15:...|    3|          9.0|
# +--------------------+-----+-------------+

# %%
writeTable.stop()
# Out:
# 26/04/08 13:15:41 WARN DAGScheduler: Failed to cancel job group b5cbac44-8e38-47ee-8eb3-9ba125337319. Cannot find active jobs for it.
# 26/04/08 13:15:41 WARN DAGScheduler: Failed to cancel job group b5cbac44-8e38-47ee-8eb3-9ba125337319. Cannot find active jobs for it.

# %% [markdown]
# The table still exists after we stop the query.

# %%
spark.sql("select * from my_table").show()
# Out:
# +--------------------+-----+-------------+
# |           timestamp|value|squared_value|
# +--------------------+-----+-------------+
# |2026-04-08 13:15:...|    0|          0.0|
# |2026-04-08 13:15:...|    1|          1.0|
# |2026-04-08 13:15:...|    2|          4.0|
# |2026-04-08 13:15:...|    3|          9.0|
# |2026-04-08 13:15:...|    4|         16.0|
# |2026-04-08 13:15:...|    5|         25.0|
# +--------------------+-----+-------------+

# %% [markdown]
# # Aggregating Over Windows
#
# Let's do a more complicated example where we were are reading in csv files from a folder and doing aggregations over time windows. This implies that our data will have some timestamps associated with it!
#
# First we'll need some data to stream. We'll read in the `neuralgia.csv` file we've seen previously in the course. Then we'll add a time stamp and output parts of the data to `.csv` files that will be read in via a stream.
#
# **We don't want to submit this code right now! We'll submit this in a python console in another window to simulate the idea of getting new data in.** We can create a python console by going to File -> New -> Console and selecting the Python 3 kernel.

# %%
#Read in some data to sample from
import pandas as pd
neuralgia = pd.read_csv("https://www4.stat.ncsu.edu/online/datasets/neuralgia.csv")

#Now a for loop to sample a few rows and output them to a data set
#Put a pause in as well
import numpy as np
import time

for i in range(0,10):
    #randomly sample a few rows
    temp = neuralgia.loc[np.random.randint(neuralgia.shape[0], size = 5)]
    temp["timestamp"] = [time.strftime("%H:%M:%S", time.localtime())]*5
    temp.to_csv("csv_neuralgia/neuralgia" + str(i) + ".csv", index = False, header = False)
    time.sleep(20)

# %% [markdown]
# Ok, when we get files in the `csv_neuralgia` directory we want to read those in. Let's set up the schema for that and read in the files as as stream.

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()
from pyspark.sql.types import StructType

#set up schema
myschema = StructType().add("Treatment", "string").add("Sex", "string").add("Age", "integer").add("Duration", "integer").add("Pain", "string").add("timestamp", "timestamp")
#set up the stream
df = spark.readStream.schema(myschema).csv("csv_neuralgia")

# %% [markdown]
# We now want to do some aggregations on the data. Specifically, we'll group the data by the "Sex" column and find the average "Duration" of pain. To start with, let's just output this to the console to see if it is working **(no windowing yet)**!

# %%
#do our aggregations
agg = df.groupBy("Sex").avg("Duration")
#write out the results to the console to start with
myquery = agg.writeStream.outputMode("complete").format("console").start()
# Out:
# 26/04/08 13:18:04 WARN ResolveWriteToStream: Temporary checkpoint location created which is deleted normally when the query didn't fail: /tmp/temporary-adf28723-dc5d-41be-9d1d-5a0895046588. If it's required to delete it under any circumstances, please set spark.sql.streaming.forceDeleteTempCheckpointLocation to true. Important to know deleting temp checkpoint folder is best effort.
# 26/04/08 13:18:04 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# +---+-------------+
# |Sex|avg(Duration)|
# +---+-------------+
# |  F|         17.0|
# |  M|          9.0|
# +---+-------------+
# -------------------------------------------
# Batch: 1
# -------------------------------------------
# +---+-------------+
# |Sex|avg(Duration)|
# +---+-------------+
# |  F|         14.0|
# |  M|         16.2|
# +---+-------------+
# -------------------------------------------
# Batch: 2
# -------------------------------------------
# +---+------------------+
# |Sex|     avg(Duration)|
# +---+------------------+
# |  F|16.142857142857142|
# |  M|            14.125|
# +---+------------------+
# -------------------------------------------
# Batch: 3
# -------------------------------------------
# +---+------------------+
# |Sex|     avg(Duration)|
# +---+------------------+
# |  F| 16.88888888888889|
# |  M|13.454545454545455|
# +---+------------------+
# -------------------------------------------
# Batch: 4
# -------------------------------------------
# +---+------------------+
# |Sex|     avg(Duration)|
# +---+------------------+
# |  F|              20.0|
# |  M|13.583333333333334|
# +---+------------------+
# -------------------------------------------
# Batch: 5
# -------------------------------------------
# +---+------------------+
# |Sex|     avg(Duration)|
# +---+------------------+
# |  F|            22.625|
# |  M|14.642857142857142|
# +---+------------------+

# %% [markdown]
# Now that this is running, jump over to a python console and submit the code that reads in the data and emulates it streaming into a folder. Note that the working directory of that console is whatever you have your file viewer on the left set to. You may need to modify the path to write to! We should see it update above once that code is running!

# %%
myquery.stop()
# Out:
# 26/04/08 13:22:10 WARN DAGScheduler: Failed to cancel job group 8bfb7ba8-a203-411c-9ed2-397d8ca321f6. Cannot find active jobs for it.
# 26/04/08 13:22:10 WARN DAGScheduler: Failed to cancel job group 8bfb7ba8-a203-411c-9ed2-397d8ca321f6. Cannot find active jobs for it.

# %% [markdown]
# We want to do the same thing as above but find aggregations over windows of time rather than overall. We'll use the `window()` function with the `timestamp` column to accomplish this.

# %%
#Now including windowing
from pyspark.sql.functions import window, col
#'listen' on the same folder
df = spark.readStream.schema(myschema).csv("csv_neuralgia")
#do our aggregations with a window of 30 seconds, no overlap.
agg = df.groupBy(
            window("timestamp", "30 seconds", "30 seconds"),
            "Sex") \
        .avg("Duration")
#write it!
windowQuery = agg.writeStream.outputMode("complete").format("console").start()
# Out:
# 26/04/08 13:52:36 WARN ResolveWriteToStream: Temporary checkpoint location created which is deleted normally when the query didn't fail: /tmp/temporary-43c2d05b-d1b8-4625-9809-6ee51a74fbaa. If it's required to delete it under any circumstances, please set spark.sql.streaming.forceDeleteTempCheckpointLocation to true. Important to know deleting temp checkpoint folder is best effort.
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# +--------------------+---+------------------+
# |              window|Sex|     avg(Duration)|
# +--------------------+---+------------------+
# |{2026-04-08 13:52...|  F|19.333333333333332|
# |{2026-04-08 13:52...|  M|              11.5|
# +--------------------+---+------------------+
# -------------------------------------------
# Batch: 1
# -------------------------------------------
# +--------------------+---+------------------+
# |              window|Sex|     avg(Duration)|
# +--------------------+---+------------------+
# |{2026-04-08 13:52...|  F|19.333333333333332|
# |{2026-04-08 13:53...|  F|              18.0|
# |{2026-04-08 13:53...|  M|              20.0|
# |{2026-04-08 13:52...|  M|              11.5|
# +--------------------+---+------------------+
# -------------------------------------------
# Batch: 2
# -------------------------------------------
# +--------------------+---+------------------+
# |              window|Sex|     avg(Duration)|
# +--------------------+---+------------------+
# |{2026-04-08 13:52...|  F|19.333333333333332|
# |{2026-04-08 13:53...|  F|              23.0|
# |{2026-04-08 13:53...|  M|              20.0|
# |{2026-04-08 13:52...|  M|              11.5|
# +--------------------+---+------------------+
# -------------------------------------------
# Batch: 3
# -------------------------------------------
# +--------------------+---+------------------+
# |              window|Sex|     avg(Duration)|
# +--------------------+---+------------------+
# |{2026-04-08 13:53...|  M|              19.0|
# |{2026-04-08 13:52...|  F|19.333333333333332|
# |{2026-04-08 13:53...|  F|              23.0|
# |{2026-04-08 13:53...|  M|              20.0|
# |{2026-04-08 13:52...|  M|              11.5|
# |{2026-04-08 13:53...|  F|              22.5|
# +--------------------+---+------------------+

# %% [markdown]
# Before submitting the first chunk of code, clear out your `csv_neuralgia` folder (delete the `.csv` files). Then submit the first chunk of code to a console again and see it update above!

# %%
windowQuery.stop()
# Out:
# 26/04/08 13:53:47 WARN DAGScheduler: Failed to cancel job group 7b5d02a3-bc8e-4f83-9ac8-fd3954fb5bbf. Cannot find active jobs for it.
# 26/04/08 13:53:47 WARN DAGScheduler: Failed to cancel job group 7b5d02a3-bc8e-4f83-9ac8-fd3954fb5bbf. Cannot find active jobs for it.

# %% [markdown]
# We are ready to include a watermark as well. We do so with the `.withWatermark()` method! This will allow us to output to a file (like .csv) when doing aggregations.

# %%
#reset our spark object
spark = SparkSession.builder.getOrCreate()
#spark.conf.set("spark.sql.adaptive.enabled", "false")
#'listen' on the same folder
df = spark.readStream.schema(myschema).csv("csv_neuralgia")
#do our aggregations with a window of 30 seconds, no overlap. Provide a 15 second watermark
agg = df \
        .withWatermark("timestamp", "2 seconds") \
        .groupBy(
            window("timestamp", "30 seconds", "30 seconds"),
            "Sex") \
        .avg("Duration")
#now the window column isn't a type that can be sent to a csv...
#instead cast it to a string and we'll be all set
agg2 = agg \
        .select(col("Sex"),
                col("avg(Duration)").alias("Avg_Duration"),
                col("Window").cast("string")
               )
#write it!
windowWaterQuery = agg2 \
                    .writeStream \
                    .outputMode("append") \
                    .option("checkpointlocation", "check") \
                    .format("csv") \
                    .option("path", "output_csv/") \
                    .start()

# %% [markdown]
# Again, clear out your `csv_neuralgia` folder and resubmit our code. After that runs for a minute, we'll stop the query! (Note we aren't outputting to the console so we won't see the output here!) You'll want to create a `output_csv` folder to store the files in. If you are rerunning things, make sure to delete or remove the `check` folder and create a new *empty* `output_csv` folder.

# %%
windowWaterQuery.stop()

# %% [markdown]
# The output csv is actually stored in pieces over my local cluster. We can `coalesce` that into a single file with the code below.

# %%
allsafiles = spark.read.option('header', 'false').csv("output_csv/part-*.csv")
allsafiles.coalesce(1).write.format("csv").option("header","false").mode("overwrite").save("output_csv/final")
#ignore the warning thing that comes up! The final file is still created and shows the calculated values.

# %% [markdown]
# # Streaming Joins Example

# %% [markdown]
# First let's do our set up and read in a static spark SQL data frame representing ad *impressions* data.

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()
from pyspark.sql.types import StructType

adImpressionSchema = StructType().add('adId', "integer").add('impressionTime', 'timestamp')
#First read in a static dataframe
staticDF = spark.read.csv('data/impressions.csv', schema = adImpressionSchema, header = True)
staticDF.show(10)
# Out:
# +----+--------------------+
# |adId|      impressionTime|
# +----+--------------------+
# |   0|2022-01-01 00:02:...|
# |   1|2022-01-01 00:05:...|
# |   2|2022-01-01 00:12:...|
# |   3|2022-01-01 00:13:...|
# |   4|2022-01-01 00:14:...|
# |   5|2022-01-01 00:19:...|
# |   6|2022-01-01 00:21:...|
# |   7|2022-01-01 00:21:...|
# |   8|2022-01-01 00:27:...|
# |   9|2022-01-01 00:28:...|
# +----+--------------------+
# only showing top 10 rows

# %% [markdown]
# Great, we will now place some *click* data into a folder that is being monitored. This will be joined with the ad data on the `adId` column. (We'll just drop a couple files in the folder being monitored and see that it is working.)

# %%
#Now set up the stream to take in data from the .csv
adClickSchema = StructType().add('adId', "integer").add('clickTime', 'timestamp')
df = spark.readStream.schema(adClickSchema).csv("click_csv_files")

#Set up the join and start the query!
joinquery = staticDF \
                .join(df, "adId", "inner") \
                .writeStream.outputMode("append") \
                .format("console") \
                .start()
# Out:
# 26/04/08 14:09:43 WARN ResolveWriteToStream: Temporary checkpoint location created which is deleted normally when the query didn't fail: /tmp/temporary-73922ef6-6fa7-465a-bbcc-4d0e22e806e7. If it's required to delete it under any circumstances, please set spark.sql.streaming.forceDeleteTempCheckpointLocation to true. Important to know deleting temp checkpoint folder is best effort.
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# +----+--------------------+--------------------+
# |adId|      impressionTime|           clickTime|
# +----+--------------------+--------------------+
# |  35|2022-01-01 01:24:...|2022-01-01 01:30:...|
# |  38|2022-01-01 01:33:...|2022-01-01 01:37:...|
# |  58|2022-01-01 02:30:...|2022-01-01 02:42:...|
# |  90|2022-01-01 04:02:...|2022-01-01 04:10:...|
# |  94|2022-01-01 04:11:...|2022-01-01 04:13:...|
# +----+--------------------+--------------------+
#
# -------------------------------------------
# Batch: 1
# -------------------------------------------
# +----+--------------------+--------------------+
# |adId|      impressionTime|           clickTime|
# +----+--------------------+--------------------+
# | 117|2022-01-01 05:26:...|2022-01-01 05:29:...|
# | 123|2022-01-01 05:51:...|2022-01-01 06:03:...|
# | 127|2022-01-01 06:04:...|2022-01-01 06:16:...|
# | 140|2022-01-01 06:41:...|2022-01-01 06:45:...|
# | 170|2022-01-01 07:56:...|2022-01-01 08:07:...|
# | 190|2022-01-01 08:57:...|2022-01-01 09:05:...|
# | 197|2022-01-01 09:25:...|2022-01-01 09:34:...|
# +----+--------------------+--------------------+
#
# -------------------------------------------
# Batch: 2
# -------------------------------------------
# +----+--------------------+--------------------+
# |adId|      impressionTime|           clickTime|
# +----+--------------------+--------------------+
# | 246|2022-01-01 12:13:...|2022-01-01 12:20:...|
# | 251|2022-01-01 12:17:...|2022-01-01 12:26:...|
# | 252|2022-01-01 12:18:...|2022-01-01 12:18:...|
# | 260|2022-01-01 12:38:...|2022-01-01 12:38:...|
# | 313|2022-01-01 14:42:...|2022-01-01 14:52:...|
# | 319|2022-01-01 14:46:...|2022-01-01 14:49:...|
# | 322|2022-01-01 15:01:...|2022-01-01 15:11:...|
# | 335|2022-01-01 15:38:...|2022-01-01 15:42:...|
# | 351|2022-01-01 16:47:...|2022-01-01 16:48:...|
# | 355|2022-01-01 17:01:...|2022-01-01 17:09:...|
# | 399|2022-01-01 19:02:...|2022-01-01 19:06:...|
# | 402|2022-01-01 19:12:...|2022-01-01 19:16:...|
# | 415|2022-01-01 19:39:...|2022-01-01 19:53:...|
# | 419|2022-01-01 19:48:...|2022-01-01 19:51:...|
# | 458|2022-01-01 21:32:...|2022-01-01 21:37:...|
# | 459|2022-01-01 21:33:...|2022-01-01 21:34:...|
# | 473|2022-01-01 22:17:...|2022-01-01 22:22:...|
# | 480|2022-01-01 22:34:...|2022-01-01 22:35:...|
# +----+--------------------+--------------------+

# %%
joinquery.stop()
